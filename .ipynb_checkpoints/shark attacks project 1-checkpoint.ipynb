# %% [markdown]
# # Shark Attach data Analysis:
#
# ## First, we will import some libraries

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# ## Lets import the data through the notebook

# %%
shark_attack = pd.read_csv('C:/Users/Lucas Angulski/Documents/GitHub/Ironhack-DA/project 1/attacks.csv', encoding='latin1')

# %%
pd.options.display.max_columns = None

shark_attack.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
#checking the shape of the data 
print(f'\033[95m {shark_attack.shape}\n')
##this means that we have 24 types of data and over 25k  entries##



#checking the size of the data
print(f'\033[0m \n {shark_attack.size}')
## The data have over 61k elements
# Out:
#  (25723, 24)
#
#
#  617352

# %%
shark_attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
#lets check the columns types

shark_attack.dtypes

##we can use .drop_duplicates() to eliminate duplicated values
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
# are there any cols with null values?


empty_col =  shark_attack.isnull().sum()

empty_col
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
##we can use .drop_duplicates() to eliminate duplicated values

#lets start cleaning the data:

bef = len(shark_attack)
print(bef)
shark_attack_1 = shark_attack.drop_duplicates()

aft= len(shark_attack_1)
print(aft)

print(f'Number of duplicated records removed {bef-aft}')
# Out:
# 25723
# 6312
# Number of duplicated records removed 19411

# %%
shark_attack_1.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                                             Location      Activity  \
# ...

# %%
shark_attack_1["Country"][:10]
# Out:
# 0          USA
# 1          USA
# 2          USA
# 3    AUSTRALIA
# 4       MEXICO
# 5    AUSTRALIA
# 6       BRAZIL
# 7          USA
# 8          USA
# 9          USA
# Name: Country, dtype: object

# %%
shark_attack_1['Year']
# Out:
# 0        2018.0
# 1        2018.0
# 2        2018.0
# 3        2018.0
# 4        2018.0
#           ...
# 6307        NaN
# 6308        NaN
# 6309        NaN
# 8702        NaN
# 25722       NaN
# Name: Year, Length: 6312, dtype: float64

# %%
print('\n.Unique values in column Year:', shark_attack_1.Year.unique())
# Out:
# .Unique values in column Year: [2018. 2017.   nan 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008.
#  2007. 2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996.
#  1995. 1984. 1994. 1993. 1992. 1991. 1990. 1989. 1969. 1988. 1987. 1986.
#  1985. 1983. 1982. 1981. 1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973.
#  1972. 1971. 1970. 1968. 1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960.
#  1959. 1958. 1957. 1956. 1955. 1954. 1953. 1952. 1951. 1950. 1949. 1948.
#  1848. 1947. 1946. 1945. 1944. 1943. 1942. 1941. 1940. 1939. 1938. 1937.
#  1936. 1935. 1934. 1933. 1932. 1931. 1930. 1929. 1928. 1927. 1926. 1925.
#  1924. 1923. 1922. 1921. 1920. 1919. 1918. 1917. 1916. 1915. 1914. 1913.
#  1912. 1911. 1910. 1909. 1908. 1907. 1906. 1905. 1904. 1903. 1902. 1901.
#  1900. 1899. 1898. 1897. 1896. 1895. 1894. 1893. 1892. 1891. 1890. 1889.
#  1888. 1887. 1886. 1885. 1884. 1883. 1882. 1881. 1880. 1879. 1878. 1877.
# ...

# %%
shark_attack_1 = shark_attack_1[shark_attack_1['Year']>500].sort_values(by=['Year'])


display(shark_attack_1)
# Out:
#        Case Number                      Date    Year        Type  \
# 6173    1543.00.00                  Ca. 1543  1543.0  Unprovoked
# 6172    1554.00.00                  Ca. 1554  1554.0  Unprovoked
# 6171    1555.00.00                      1555  1555.0  Unprovoked
# 6170  1580.01.10.R  Letter dated 10-Jan-1580  1580.0  Unprovoked
# 6169    1595.00.00                      1595  1595.0  Unprovoked
# ...            ...                       ...     ...         ...
# 1       2018.06.18               18-Jun-2018  2018.0  Unprovoked
# 24      2018.04.22               22-Apr-2018  2018.0  Unprovoked
# 12    2018.05.13.b               13-May-2018  2018.0  Unprovoked
# 11      2018.05.21               21-May-2018  2018.0  Unprovoked
# 0       2018.06.25               25-Jun-2018  2018.0     Boating
#
#                        Country                         Area  \
# 6173                 VENEZUELA  Magarita or Cubagua Islands
# 6172                    FRANCE            Nice & Marseilles
# ...

# %%
print('\n.Unique values in column Year:', shark_attack_1.Year.unique())
# Out:
# .Unique values in column Year: [1543. 1554. 1555. 1580. 1595. 1617. 1637. 1638. 1642. 1700. 1703. 1721.
#  1723. 1733. 1738. 1742. 1748. 1749. 1751. 1753. 1755. 1758. 1764. 1767.
#  1771. 1776. 1779. 1780. 1783. 1784. 1785. 1786. 1787. 1788. 1791. 1792.
#  1797. 1800. 1801. 1802. 1803. 1804. 1805. 1807. 1808. 1810. 1811. 1812.
#  1815. 1816. 1817. 1818. 1819. 1822. 1823. 1825. 1826. 1827. 1828. 1829.
#  1830. 1831. 1832. 1834. 1835. 1836. 1837. 1839. 1840. 1841. 1842. 1844.
#  1845. 1846. 1847. 1848. 1849. 1850. 1851. 1852. 1853. 1855. 1856. 1857.
#  1858. 1859. 1860. 1861. 1862. 1863. 1864. 1865. 1866. 1867. 1868. 1869.
#  1870. 1871. 1872. 1873. 1874. 1875. 1876. 1877. 1878. 1879. 1880. 1881.
#  1882. 1883. 1884. 1885. 1886. 1887. 1888. 1889. 1890. 1891. 1892. 1893.
#  1894. 1895. 1896. 1897. 1898. 1899. 1900. 1901. 1902. 1903. 1904. 1905.
#  1906. 1907. 1908. 1909. 1910. 1911. 1912. 1913. 1914. 1915. 1916. 1917.
# ...

# %%
shark_attack_1.size
# Out:
# 138864

# %%
import geopandas
# Out:
# PROJ: proj_create_from_database: SQLite error on SELECT name, type, coordinate_system_auth_name, coordinate_system_code, datum_auth_name, datum_code, area_of_use_auth_name, area_of_use_code, text_definition, deprecated FROM geodetic_crs WHERE auth_name = ? AND code = ?: no such column: area_of_use_auth_name

# %%
shark_attack_1.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
shark_attack_1 = shark_attack_1.drop(['Unnamed: 22','Unnamed: 23'],axis=1)

# %%
shark_attack_1.head(1)
# Out:
#   Case Number         Date    Year     Type Country        Area  \
# 0  2018.06.25  25-Jun-2018  2018.0  Boating     USA  California
#
#                       Location  Activity         Name Sex  Age  \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F  57
#
#                                               Injury Fatal (Y/N)   Time  \
# 0  No injury to occupant, outrigger canoe and pad...           N  18h00
#
#       Species  Investigator or Source                   pdf  \
# 0  White shark       R. Collier, GSAF  2018.06.25-Wolfe.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
#
#   Case Number.2  original order
# 0    2018.06.25          6303.0

# %%
map = worldmap.merge(shark_attack_1,on='Country',how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8e8bc7b25950> in <module>
# ----> 1 map = worldmap.merge(shark_attack_1,on='Country',how='left')
#
# NameError: name 'worldmap' is not defined
