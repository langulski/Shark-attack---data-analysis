# %% [markdown]
# # Shark attack
#
#
# <img src="https://cdn1.theinertia.com/wp-content/gallery/surfest/vicente-lang-2-670x446.jpg" width="500" align="center">
#
#
#
# A party of surfists are planning to surf overseas. They would love to surf in other countries seas, but they are afraid of being attacked by sharks or even worse, becoming their food. ;)
#
# For this we are going to help them decide what locations they should avoid surfing at.

# %% [markdown]
# # This file is to adjust the order of the data cleaning

# %% [markdown]
# # 1.1  Reading the file and dropping duplicates

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import folium
import numpy as np
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
pd.options.display.max_columns = None
pd.options.display.max_rows = None
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 14}

plt.rc('font', **font)
df= pd.read_csv('C:/Users/Lucas Angulski/Documents/GitHub/Ironhack-DA/project 1/attacks.csv', encoding='latin1')

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25          6303.0         NaN         NaN
# 1    2018.06.18          6302.0         NaN         NaN
# 2    2018.06.09          6301.0         NaN         NaN
# 3    2018.06.08          6300.0         NaN         NaN
# 4    2018.06.04          6299.0         NaN         NaN

# %%
#checking the shape of the data 
print(f'\033[95m {df.shape}\n')
##this means that we have 24 types of data and over 25k  entries##

#checking the size of the data
print(f'\033[0m \n {df.size}')
## The data have over 61k elements
# Out:
#  (25723, 24)
#
#
#  617352

# %%
df.info()

## the last two columns have no relevant information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
##we can use .drop_duplicates() to eliminate duplicated values

#lets start cleaning the data:

bef = len(df)
print(bef)
df = df.drop_duplicates()

aft= len(df)
print(aft)

print(f'Number of duplicated records removed {bef-aft}')
# Out:
# 25723
# 6312
# Number of duplicated records removed 19411

# %% [markdown]
# from 25723 rows we left with 'only' 6312 just removing duplicated items.

# %% [markdown]
# ## lets start cleaning the data

# %%
# print(set(df['Activity']))

# %%
# df['Activity'].value_counts()

# %%
len(df['Activity'])
# Out:
# 6312

# %% [markdown]
# ##  1.2 cleaning Activities:
#
# <img src="https://i.pinimg.com/originals/00/a7/fe/00a7fe30e8db16d49a46b7cb55ec799d.png" width="500" align="center">
#
#
#
#
#
#
#
#
#
#
# ### intro
#
# lets define the activities into fewer categories. The column  has many items described not only as a single activity, We will
# try to divide them  into sub-categories for better understanding of the attacks.
#
# In order to divide into these categories we will look up for the most known activities that are done in water
#
# below we will find key words using the famous <b>REGEX </b>.
#
# swimming = swimming / swim
#
# walk = /Wading /  Walking
#
# Surfing = surfing  or boogie boarding /surfng
#
# sailing = boating /canoeing / sailing /raft / Kayak /floating
#
# ep_boats = ship/yacht  (engined powered)
#
# Kite/kiting = kitesurfing/ kite boarding/ Skimboarding
#
# fishing = Spearfishing / fishing /net
#
# jet/skiing =  jetskiing /skiing / water-skiing
#
# feeding sharks =  feeding sharks
#
# dive = scuba diving / scuba / dive / Snorkeling
#
# taking photos = photos / photo shooting
#
# other

# %%
# activity is defined as object, in order to use regex we need to convert it into STR.

#  REGEX HELPER : https://regexr.com/

# %%
df['Activity'] = df['Activity'].astype(str).str.lower()
df['Activity'] = df['Activity'].str.strip()

# %%
df['Activity'].dropna(inplace = True)

# %%
#https://www.geeksforgeeks.org/extract-punctuation-from-the-specified-column-of-dataframe-using-regex/#:~:text=re.findall%20%28%29%20function%20is%20used%20to%20extract%20all,pattern%20in%20string%2C%20as%20a%20list%20of%20strings.
def activity_Cleaner(row):
    #[SsWw][AaWw][DdIilL][/IikKmM][iIMmNn/][g]*
    #swimming = swimming / swim / jump 
    swimming_list = re.findall('[sj][wu][im][pm][m]?\w*',row['Activity'])
    #walk = /Wading /  Walking / 
    walking_list = re.findall('[w][a][dl][k]?\w*',row['Activity'])
    #Surfing = surfing  or boogie boarding /surfng / body surfing
    surfing_list = re.findall('[sb][ou][ador][rygf][ndi][e]?\w*',row['Activity'])
    #sailing = boating /canoeing / sailing /raft / floating
    sailing_list = re.findall('[bcsrkf][aol][anifyo][atol][teki]?\w*',row['Activity'])
    #ep_boats = ship/yacht  (engined powered)
    ep_boats_list =  re.findall('[sy][ha][ic][hp][t]?\w*',row['Activity'])
    #Kite/kiting = kitesurfing/ kite boarding/ Skimboarding
    kite_list =  re.findall('[sk][ik][it][mie][n]?\w*',row['Activity'])
    #fishing = Spearfishing / fishing /net
    fish_list = re.findall('[fn][ie][st][h]?\w*',row['Activity'])
    #jet/skiing =  jetskiing /skiing / water-skiing
    jet_list = re.findall('[s][k][i][i][n]\w*',row['Activity'])
    #dive = scuba diving / scuba / dive / Snorkeling
    dive_list = re.findall('[ds][inc][vuo][eibr][ak]?\w*',row['Activity'])
    #feeding sharks =  feeding sharks
    feed_list = re.findall('[f][e][e][d]\w*',row['Activity'])
    #taking photos = photos / photo shooting
    photo_list = re.findall('[p][h][o][t][o]\w*',row['Activity'])
    
    ## reading a list where it will store each time the word appears in each row, if its different,
    ##it changes the value of the row 
    ## to what the 'return' has been set.
    
    if len(swimming_list) !=0:
        return 'swimming'
    elif len(walking_list) !=0:
        return 'walking'
    
    elif len(surfing_list) !=0:
        return 'surfing'
    
    elif len(sailing_list) !=0:
        return 'sailing'
    
    elif len(ep_boats_list) !=0:
        return 'ep_boats'
    
    elif len(kite_list) !=0:
        return 'kiting'
    
    elif len(fish_list) !=0:
        return 'fishing'
    
    elif len(jet_list) !=0:
        return 'skiing'
    
    elif len(dive_list) !=0:
        return 'diving'
    
    elif len(feed_list) !=0:
        return 'feeding'
    
    elif len(photo_list) !=0:
        return 'Photoshooting'

    else:
        return  'other'

# %%
df['Activity'] = df.apply(activity_Cleaner, axis = 1)

# %%
df['Activity'].value_counts()
# Out:
# surfing          1404
# other            1306
# swimming         1159
# fishing          1146
# diving            614
# sailing           333
# walking           221
# ep_boats           70
# kiting             44
# feeding            12
# Photoshooting       3
# Name: Activity, dtype: int64

# %% [markdown]
# ##  1.3 Cleaning Fatals
#
# <img src="https://www.nicepng.com/png/detail/320-3206388_sharkwithdiver-cartoon-shark-eating-a-man.png" width="300" align="center">
#
#
# For this part we will define a function in order to have a better visualization of the lethal attacks.
#
# checking the data, we can see that in the columns 'Injury' and 'Species'  also have some info about the cases involving deaths
# that are not listed  inside the Column 'Fatals'
#
#
# in order to adjust this column we will have to check the values inside the other columns and relate them using *REGEX*

# %%
df = df.rename(columns={'Fatal (Y/N)':'Fatal'})
df['Fatal'] = df['Fatal'].str.strip()
df = df.rename(columns={'Species ':'Species'})
df['Species'] = df['Species'].str.strip()
df['Species'] = df['Species'].astype(str).str.lower()

df['Injury'] = df['Injury'].str.strip()
df['Injury'] = df['Injury'].astype(str).str.lower()

# %%
df.Fatal.unique()
# Out:
# array(['N', 'Y', nan, 'M', 'UNKNOWN', '2017', 'y'], dtype=object)

# %%
df[df['Fatal']=='2017']
# Out:
#     Case Number         Date    Year      Type Country      Area  Location  \
# 786  2012.06.10  10-Jun-2012  2012.0  Provoked   ITALY  Sardinia  Muravera
#
#     Activity          Name Sex  Age                                    Injury  \
# 786   diving  Giorgio Zara    M  57  lower left leg injured provoked accident
#
#     Fatal     Time           Species Investigator or Source  \
# 786  2017  Morning  blue shark, 2.5m    D. Puddo, 6/11/2012
#
#                      pdf                                       href formula  \
# 786  2012.06.10-Zara.pdf  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...    2012.06.10
#
#     Case Number.2  original order Unnamed: 22 Unnamed: 23
# 786    2012.06.10          5517.0         NaN         NaN

# %%
df = df.drop(index=[786])

# %%
(~df.isnull()).sum().sort_values(ascending=False)
# Out:
# Species                   6311
# Injury                    6311
# Activity                  6311
# Case Number               6309
# original order            6308
# Case Number.2             6301
# href                      6301
# Date                      6301
# Case Number.1             6301
# pdf                       6301
# href formula              6300
# Year                      6299
# Type                      6297
# Investigator or Source    6284
# Country                   6251
# Name                      6091
# Area                      5846
# Fatal                     5762
# Location                  5761
# Sex                       5736
# Age                       3470
# Time                      2947
# Unnamed: 23                  2
# Unnamed: 22                  1
# dtype: int64

# %%
#taking closer look to the data, we see that some there are some null values that we can get rid off.
df.dropna(subset=['Fatal'],inplace=True)

# %%
(~df.isnull()).sum().sort_values(ascending=False)
# Out:
# Fatal                     5762
# Injury                    5762
# original order            5762
# Case Number.2             5762
# Case Number.1             5762
# href                      5762
# Activity                  5762
# pdf                       5762
# Species                   5762
# Date                      5762
# href formula              5761
# Case Number               5761
# Year                      5761
# Type                      5759
# Investigator or Source    5750
# Country                   5717
# Name                      5609
# Area                      5358
# Location                  5279
# Sex                       5275
# Age                       3243
# Time                      2801
# Unnamed: 23                  2
# Unnamed: 22                  1
# dtype: int64

# %%
# print(set(df['Injury']))

# %%
# print(set(df['Species']))

# %%
df[(df['Fatal']=='UNKNOWN')]



## the 'UNKNOWN'
# Out:
#        Case Number                        Date    Year          Type  \
# 624     2013.09.08                 08-Sep-2013  2013.0    Unprovoked
# 1270  2008.04.20.a                 20-Apr-2008  2008.0    Unprovoked
# 2250    1997.06.07                 07-Jun-1997  1997.0    Unprovoked
# 2260    1997.02.21                 21-Feb-1997  1997.0    Unprovoked
# 2267    1996.12.29                 29-Dec-1996  1996.0    Unprovoked
# 2295    1996.07.14                 14-Jul-1996  1996.0    Unprovoked
# 2307  1996.04.28.b                 28-Apr-1996  1996.0    Unprovoked
# 2323  1996.01.14.b                 14-Jan-1996  1996.0    Unprovoked
# 2328    1995.12.18                 18-Dec-1995  1995.0    Unprovoked
# 2388    1995.05.18                 18-May-1995  1995.0    Unprovoked
# 2404  1995.00.00.b                        1995  1995.0    Unprovoked
# 2409    1994.12.10  Reported      10-Dec-1994   1994.0    Unprovoked
# 2648    1990.00.00                        1990  1990.0    Unprovoked
#
#                                                    Name Sex   Age  \
# 624                                              female    F  NaN
# 1270                                    Jamie Adlington    M  NaN
# 2250                                  José Luiz Lipiani    M  NaN
# 2260                                    Gersome Perreno    M  NaN
# 2267                                         Blair Hall    M   18
# 2295                                       Trimurti Day  NaN  NaN
# 2307                                        Wayne Leong    M  NaN
# 2323                                             Marris  NaN  NaN
# 2328                                   Carlton Taniyama    M  NaN
# 2388                                           Hutchins  NaN  NaN
# 2404                                               male    M  NaN
# 2409                                                NaN  NaN  NaN
# 2648                                               male    M   17
# 2650                                       Ryan Johnson    M   17
# 2661                                        John Benson    M  NaN
# 2806                                           Crawford  NaN  NaN
# 2882                                                NaN  NaN  NaN
# 2900                                          Greenwood  NaN  NaN
# 2943                                 Arnold Schwarzwood    M  NaN
# 2996                                     Giovanni Vuoso    M  NaN
# 2998                              English holiday-maker  NaN  NaN
# 3006                                     Robert Conklin    M  NaN
# 3038                                                NaN  NaN  NaN
# 3041                                             Filmer  NaN  NaN
# 3298                                            G. Cole  NaN   21
# 3396                                         David Vota    M  NaN
# 3411                                       Mr. Jurincic    M  NaN
# 3429                                      Steven Benham    M   22
# 3434                                 Douglas Kuchn, Jr.    M   18
# 3507                                             Parang  NaN  NaN
# 3545                                    Vinit Tantikarn  NaN   28
# 3552                                        Terry Adams    M  NaN
# 3712                                            Edwards  NaN  NaN
# 3774                                                NaN  NaN  NaN
# 3794                                          fisherman    M  NaN
# 3838  17' fishing launch, occupants: A. Burkitt & C....  NaN  NaN
# 3841                            Domingos Zefanias Cumbe    M   16
# 4060  12' boat. Occupants:  Capt. E.J. Wines, Maj. W...  NaN  NaN
# 4208  Japanese male, one of crew of pearl culture su...    M  NaN
# 4256                                                NaN  NaN  NaN
# 4269                                               girl    F   14
# 4310                    2 incidents north of Vero Beach  NaN  NaN
# 4323                                                NaN  NaN  NaN
# 4517                                               boat  NaN  NaN
# 4689                                               male    M  NaN
# 4786                                       another boat  NaN  NaN
# 4787                                               boat  NaN  NaN
# 4976                                                NaN  NaN  NaN
# 4998                                               boat  NaN  NaN
# 5029                        "3 shark attacks in 3 days"  NaN  NaN
# 5159                                        Mr. Daniels    M  NaN
# 5270      5 cadets from the Naval training ship Tingara    M  NaN
# 5347                                      Indian female    F  NaN
# 5409                            Lieut. James H. Stewart    M  NaN
# 5555                                       George Brown    M  NaN
# 5615                                          Anonymous  NaN  NaN
# 5653                                    Catherine Beach    F  NaN
# 5656                                Erskine H. Reynolds    M  NaN
# 5674                                         No details  NaN  NaN
# 5708                                      a pearl diver    M  NaN
# 5709                                      a pearl diver    M  NaN
# 5998                    a seaman from the John and Lucy    M   17
# 6081                                                NaN  NaN  NaN
# 6153                                          Fishermen    M  NaN
# 6165                                            sailors    M  NaN
# 6166                                     Hindu pilgrims  NaN  NaN
# 6167                                      Indian people  NaN  NaN
# 6169                                               male    M  NaN
# 6171                                               male    M  NaN
# 6172                              males (wearing armor)    M  NaN
# 6277                      male, the Sergeant of Marines    M  NaN
#
#                                                  Injury    Fatal  \
# 624                                          no details  UNKNOWN
# 1270                                                nan  UNKNOWN
# 2250                                                nan  UNKNOWN
# 2260                                         no details  UNKNOWN
# 2267                                                nan  UNKNOWN
# 2295                                         no details  UNKNOWN
# 2307                                         no details  UNKNOWN
# 2323                                         no details  UNKNOWN
# 2328                                         no details  UNKNOWN
# 2388                                         no details  UNKNOWN
# 2404                                         no details  UNKNOWN
# 2409                                         no details  UNKNOWN
# 2648                                                nan  UNKNOWN
# 2650        no details, "recovering in darwin hospital"  UNKNOWN
# 2661                                         no details  UNKNOWN
# 2806                                         no details  UNKNOWN
# 2882                                         no details  UNKNOWN
# 2900                                         no details  UNKNOWN
# 2943                                         no details  UNKNOWN
# 2996                                         no details  UNKNOWN
# 2998                                         no details  UNKNOWN
# 3006                                         no details  UNKNOWN
# 3038                                                nan  UNKNOWN
# 3041                                         no details  UNKNOWN
# 3298                                                nan  UNKNOWN
# 3396                                         no details  UNKNOWN
# 3411                                         no details  UNKNOWN
# 3429                                         no details  UNKNOWN
# 3434                                                nan  UNKNOWN
# 3507            no details, listed as provoked incident  UNKNOWN
# 3545                                         no details  UNKNOWN
# 3552  involved a speared shark but no other details ...  UNKNOWN
# 3712                                                nan  UNKNOWN
# 3774                                         no details  UNKNOWN
# 3794      details unknown, possibly a provoked incident  UNKNOWN
# 3838                                                nan  UNKNOWN
# 3841                                                nan  UNKNOWN
# 4060                                                nan  UNKNOWN
# 4208  man landed at cape levêque lighthouse in criti...  UNKNOWN
# 4256                                         no details  UNKNOWN
# 4269                                         no details  UNKNOWN
# 4310                                         no details  UNKNOWN
# 4323                                         no details  UNKNOWN
# 4517                                                nan  UNKNOWN
# 4689              unprovoked, but circumstances unknown  UNKNOWN
# 4786                                         no details  UNKNOWN
# 4787                                         no details  UNKNOWN
# 4976                                                nan  UNKNOWN
# 4998                                         no details  UNKNOWN
# 5029                                         no details  UNKNOWN
# 5159                                         no details  UNKNOWN
# 5270                    shark involvement not confirmed  UNKNOWN
# 5347                                         no details  UNKNOWN
# 5409             calf removed, not known if he survived  UNKNOWN
# 5555                                          no injury  UNKNOWN
# 5615                                         no details  UNKNOWN
# 5653                                          no injury  UNKNOWN
# 5656                 "painfully injured" but no details  UNKNOWN
# 5674                                         no details  UNKNOWN
# 5708                                         no details  UNKNOWN
# 5709                                         no details  UNKNOWN
# 5998     severe bite to thigh. not known if he survived  UNKNOWN
# 6081  no details, it was the year the first settlers...  UNKNOWN
# 6153                                                nan  UNKNOWN
# 6165                                                nan  UNKNOWN
# 6166                                                nan  UNKNOWN
# 6167                                                nan  UNKNOWN
# 6169  leg severed mid-thigh, hand severed, arm above...  UNKNOWN
# 6171                                                nan  UNKNOWN
# 6172                                                nan  UNKNOWN
# 6277                                                nan  UNKNOWN
#
#                 Time                                            Species  \
# 624              NaN                                                nan
# 1270             NaN                                  tiger shark, 2.3m
# 2250             NaN                                                nan
# 2260             NaN                                                nan
# 2267           18h00                                                nan
# 2295             NaN                                                nan
# 2307             NaN                                                nan
# 4786  http://sharkattackfile.net/spreadsheets/pdf_di...    1939.11.09
# 4787  http://sharkattackfile.net/spreadsheets/pdf_di...    1939.11.06
# 4976  http://sharkattackfile.net/spreadsheets/pdf_di...    1932.11.09
# 4998  http://sharkattackfile.net/spreadsheets/pdf_di...    1932.01.11
# 5029  http://sharkattackfile.net/spreadsheets/pdf_di...  1931.00.00.a
# 5159  http://sharkattackfile.net/spreadsheets/pdf_di...  1926.00.00.a
# 5270  http://sharkattackfile.net/spreadsheets/pdf_di...    1919.03.16
# 5347  http://sharkattackfile.net/spreadsheets/pdf_di...    1914.00.00
# 5409  http://sharkattackfile.net/spreadsheets/pdf_di...  1910.00.00.a
# 5555  http://sharkattackfile.net/spreadsheets/pdf_di...    1900.09.13
# 5615  http://sharkattackfile.net/spreadsheets/pdf_di...  1897.00.00.a
# 5653  http://sharkattackfile.net/spreadsheets/pdf_di...    1894.08.21
# 5656  http://sharkattackfile.net/spreadsheets/pdf_di...    1894.06.29
# 5674  http://sharkattackfile.net/spreadsheets/pdf_di...    1893.00.00
# 5708  http://sharkattackfile.net/spreadsheets/pdf_di...  1890.00.00.d
# 5709  http://sharkattackfile.net/spreadsheets/pdf_di...  1890.00.00.c
# 5998  http://sharkattackfile.net/spreadsheets/pdf_di...    1856.02.06
# 6081  http://sharkattackfile.net/spreadsheets/pdf_di...  1836.00.00.a
# 6153  http://sharkattackfile.net/spreadsheets/pdf_di...    1755.00.00
# 6165  http://sharkattackfile.net/spreadsheets/pdf_di...  1638.00.00.R
# 6166  http://sharkattackfile.net/spreadsheets/pdf_di...  1637.00.00.R
# 6167  http://sharkattackfile.net/spreadsheets/pdf_di...  1617.00.00.R
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...    1595.00.00
# 6171  http://sharkattackfile.net/spreadsheets/pdf_di...    1555.00.00
# 6172  http://sharkattackfile.net/spreadsheets/pdf_di...    1554.00.00
# 6277  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0025
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23
# 624     2013.09.08          5679.0         NaN         NaN
# 1270  2008.04.20.a          5033.0         NaN         NaN
# 2250    1997.06.07          4053.0         NaN         NaN
# 2260    1997.02.21          4043.0         NaN         NaN
# 2267    1996.12.29          4036.0         NaN         NaN
# 2295    1996.07.14          4008.0         NaN         NaN
# 2307  1996.04.28.b          3996.0         NaN         NaN
# 2323  1996.01.14.b          3980.0         NaN         NaN
# 2328    1995.12.18          3975.0         NaN         NaN
# 2388    1995.05.18          3915.0         NaN         NaN
# 2404  1995.00.00.b          3899.0         NaN         NaN
# 2409    1994.12.10          3894.0         NaN         NaN
# 2648    1990.00.00          3655.0         NaN         NaN
# 2650    1989.12.03          3653.0         NaN         NaN
# 2661    1989.10.01          3642.0         NaN         NaN
# 2806    1986.10.01          3497.0         NaN         NaN
# 2882    1984.09.19          3421.0         NaN         NaN
# 2900    1984.03.01          3403.0         NaN         NaN
# 2943    1983.04.19          3360.0         NaN         NaN
# 2996  1982.00.00.c          3307.0         NaN         NaN
# 2998  1982.00.00.a          3305.0         NaN         NaN
# 3006    1981.10.17          3297.0         NaN         NaN
# 3038    1981.03.00          3265.0         NaN         NaN
# 3041    1981.02.07          3262.0         NaN         NaN
# 3298    1973.08.27          3005.0         NaN         NaN
# 3396  1970.04.00.a          2907.0         NaN         NaN
# 3411  1970.00.00.e          2892.0         NaN         NaN
# 3429    1969.06.27          2874.0         NaN         NaN
# 3434    1969.05.22          2869.0         NaN         NaN
# 3507  1967.09.07.b          2796.0         NaN         NaN
# 3545    1966.11.14          2758.0         NaN         NaN
# 3552    1966.09.13          2751.0         NaN         NaN
# 3712  1964.01.01.b          2591.0         NaN         NaN
# 3774  1963.00.00.b          2529.0         NaN         NaN
# 3794  1962.08.31.R          2509.0         NaN         NaN
# 3838    1962.02.02          2465.0         NaN         NaN
# 3841    1962.01.26          2462.0         NaN         NaN
# 4060  1959.09.26.a          2243.0         NaN         NaN
# 4208    1957.02.02          2095.0         NaN         NaN
# 4256    1956.03.25          2047.0         NaN         NaN
# 4269  1956.00.00.d          2034.0         NaN         NaN
# 4310  1955.00.00.f          1993.0         NaN         NaN
# 4323  1954.10.02.b          1980.0         NaN         NaN
# 4517    1949.03.00          1786.0         NaN         NaN
# 4689  1943.00.00.a          1614.0         NaN         NaN
# 4786    1939.11.09          1517.0         NaN         NaN
# 4787    1939.11.06          1516.0         NaN         NaN
# 4976    1932.11.09          1327.0         NaN         NaN
# 4998    1932.01.11          1305.0         NaN         NaN
# 5029  1931.00.00.a          1274.0         NaN         NaN
# 5159  1926.00.00.a          1144.0         NaN         NaN
# 5270    1919.03.16          1033.0         NaN         NaN
# 5347    1914.00.00           956.0         NaN         NaN
# 5409  1910.00.00.a           894.0         NaN         NaN
# 5555    1900.09.13           748.0         NaN         NaN
# 5615  1897.00.00.a           688.0         NaN         NaN
# 5653    1894.08.21           650.0         NaN         NaN
# 5656    1894.06.29           647.0         NaN         NaN
# 5674    1893.00.00           629.0         NaN         NaN
# 5708  1890.00.00.d           595.0         NaN         NaN
# 5709  1890.00.00.c           594.0         NaN         NaN
# 5998    1856.02.06           305.0         NaN         NaN
# 6081  1836.00.00.a           222.0         NaN         NaN
# 6153    1755.00.00           150.0         NaN         NaN
# 6165  1638.00.00.R           138.0         NaN         NaN
# 6166  1637.00.00.R           137.0         NaN         NaN
# 6167  1617.00.00.R           136.0         NaN         NaN
# 6169    1595.00.00           134.0         NaN         NaN
# 6171    1555.00.00           132.0         NaN         NaN
# 6172    1554.00.00           131.0         NaN         NaN
# 6277       ND.0025            26.0         NaN         NaN

# %%
import seaborn as sns
df.dropna()
fig, ax = plt.subplots(figsize=(10,5))
sns.heatmap(df.isnull(),cmap='coolwarm')
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# <AxesSubplot:>

# %% [markdown]
# by looking at the graph we can see that so far we did a good job cleaning the columns we have previously analysed.

# %%
## defining a function to clean the binary option in fatal:

def clean_Fatal(row):
    if row['Fatal'] == ('Y'):
        return 'Yes'
    elif row['Fatal'] == ('y'):
        return 'Yes'
    elif row['Fatal'] == ('N'):
        return 'No'
    elif row['Fatal'] == ('M'):
        return 'No'
    elif row['Fatal'] == 'UNKNOWN':
        return 'No'

    elif pd.isnull(row['Fatal']) == True:
        
        
        try:
            #checking Species and Injury columns 
            
            #trying to match 'FATAL' 'DEATH' 'DIED' 'DEAD'
            injury_re = re.findall('[fd][eai][tae][atd][lh]',row['Injury'])
            species_re = re.findall('[fd][eai][tae][atd][lh]',row['Species'])
        
            if len(injury_re + species_re) == 0:
                return 'No'

            else:  
                return 'Yes'
        except:
            return 'No info'
            
    else:
        return row['Fatal']

# %%
df['Fatal'] = df.apply(clean_Fatal, axis = 1)

# %%
len(df['Fatal'])
# Out:
# 5762

# %%
df['Fatal'].value_counts()
# Out:
# No     4373
# Yes    1389
# Name: Fatal, dtype: int64

# %% [markdown]
# ## 1.4 Cleaning Years
#
#
# <img src="https://www.pngitem.com/pimgs/m/304-3044302_shark-galaxy-cute-ocean-hd-png-download.png" width="300" align="center">
#
# For this column, the data is showing as 'float64' but if in the future we need to analise this with a plot tool, we might
# face some bugs.
#
# Just like the Fatal ones, we can see some  years showing '0' but in the column 'Date' we can get an estimated year of the attack.
#
# for that, we again going to define a function to return these values as year.

# %%
# df['Year'].value_counts()

# %%
#df[df['Year']<1500]

# %%
len(df['Year'])
# Out:
# 5762

# %%
df=df[df['Year']>1900]

# %%
df.dropna(subset=['Year'],inplace=True)

# %%
len(df['Year'])
# Out:
# 5086

# %%
#adding a function to return the year as a int

# same as the 

def year_Clean(row):
    year_re = re.search('([0-9]{4})',str(row))
    if year_re != 0:
        return int(year_re.group())
    else:
        return None

# %%
df['Year'] = df.apply(year_Clean, axis = 1)

# %%
df.Year.unique()
# Out:
# array([2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008,
#        2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997,
#        1996, 1995, 1984, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1987,
#        1986, 1985, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975,
#        1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967, 1966, 1965, 1964,
#        1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953,
#        1952, 1951, 1950, 1949, 1948, 1947, 1946, 1945, 1944, 1943, 1942,
#        1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932, 1931,
#        1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921, 1920,
#        1919, 1900, 1918, 1917, 1916, 1915, 1914, 1913, 1912, 1911, 1910,
#        1909, 1908, 1907, 1906, 1905, 1904, 1903, 1902, 1901], dtype=int64)

# %%
len(df.Year)
# Out:
# 5086

# %% [markdown]
# ## 1.5 Cleaning Countries
#
# Looking at the countries we might see some rows that are not really countries.
# For example there are some attacks labeled in "GULF OF ADEN" , "SOUTH ATLANTIC OCEAN"  "ATLANTIC OCEAN".
# For these rows, we are going to take a closer look and verify is there is any useful info.

# %%
df['Country'] = df['Country'].astype(str).str.upper()
df['Country'] = df['Country'].astype(str).str.strip()

# %%
df['Country'] = df['Country'].str.strip()

# %%
df['Country'].value_counts()
# Out:
# USA                                      1906
# AUSTRALIA                                1084
# SOUTH AFRICA                              487
# PAPUA NEW GUINEA                          128
# BRAZIL                                    100
# BAHAMAS                                    95
# NEW ZEALAND                                89
# MEXICO                                     70
# REUNION                                    58
# PHILIPPINES                                55
# FIJI                                       52
# NEW CALEDONIA                              50
# ITALY                                      46
# MOZAMBIQUE                                 38
# EGYPT                                      29
# CUBA                                       28
# SPAIN                                      26
# PANAMA                                     26
# SOLOMON ISLANDS                            26
# IRAN                                       25
# JAPAN                                      25
# HONG KONG                                  24
# CROATIA                                    23
# FRENCH POLYNESIA                           21
# NAN                                        20
# INDONESIA                                  18
# JAMAICA                                    18
# TONGA                                      15
# COSTA RICA                                 15
# PACIFIC OCEAN                              14
# ENGLAND                                    13
# VIETNAM                                    12
# ATLANTIC OCEAN                             11
# SOUTH CHINA SEA                             1
# BANGLADESH                                  1
# GRAND CAYMAN                                1
# WESTERN SAMOA                               1
# BRITISH ISLES                               1
# GABON                                       1
# ST. MAARTIN                                 1
# JOHNSTON ISLAND                             1
# GULF OF ADEN                                1
# RED SEA                                     1
# FEDERATED STATES OF MICRONESIA              1
# NORWAY                                      1
# ADMIRALTY ISLANDS                           1
# BRITISH WEST INDIES                         1
# MALDIVES                                    1
# PALESTINIAN TERRITORIES                     1
# NORTH SEA                                   1
# MALDIVE ISLANDS                             1
# ANDAMAN / NICOBAR ISLANDAS                  1
# CYPRUS                                      1
# Name: Country, dtype: int64

# %%
## there are some countries that we may look a little closer
#ANDAMAN / NICOBAR ISLANDAS
#RED SEA / INDIAN OCEAN
#IRAN / IRAQ 
#SOLOMON ISLANDS / VANUATU
#EGYPT / ISRAEL
#ITALY / CROATIA
#EQUATORIAL GUINEA / CAMEROON

# %%
df[df['Country']=='ANDAMAN / NICOBAR ISLANDAS']
# Out:
#      Case Number         Date  Year        Type                     Country  \
# 4140  1958.09.13  13-Sep-1958  1958  Unprovoked  ANDAMAN / NICOBAR ISLANDAS
#
#      Area Location  Activity                                     Name Sex   \
# 4140  NaN      NaN  ep_boats  Sailor of tuna vessel Daisan-Tenyo-Maru    M
#
#      Age             Injury Fatal   Time     Species Investigator or Source  \
# 4140  32  fatal, leg bitten   Yes  14h00  blue shark              M. Hosina
#
#                         pdf  \
# 4140  1958.09.13-sailor.pdf
#
#                                            href formula  \
# 4140  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 4140  http://sharkattackfile.net/spreadsheets/pdf_di...    1958.09.13
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23
# 4140    1958.09.13          2163.0         NaN         NaN

# %%
df.at[4140,'Country']='NICOBAR ISLANDS'
df.at[3957,'Country']='EGYPT' 
df.at[3957,'Area']='Suez Canal'
df.at[4140,'Country']='IRAN'
df.at[4696,'Country']='SOLOMON ISLANDS'
df.at[4619,'Country']='IRAN'
df.at[2292,'Country']='EGYPT'
df.at[2292,'Area']='South Sinai'
df.at[4934,'Country']='CROATIA'
df.at[5978,'Country']='EQUATORIAL GUINEA'

# %%
df.dropna(axis=0, subset=['Country'],inplace=True)

# %%
df['Country'].unique()
# Out:
# array(['USA', 'AUSTRALIA', 'MEXICO', 'BRAZIL', 'ENGLAND', 'SOUTH AFRICA',
#        'THAILAND', 'COSTA RICA', 'MALDIVES', 'BAHAMAS', 'NEW CALEDONIA',
#        'ECUADOR', 'MALAYSIA', 'LIBYA', 'NAN', 'CUBA', 'MAURITIUS',
#        'NEW ZEALAND', 'SPAIN', 'SAMOA', 'SOLOMON ISLANDS', 'JAPAN',
#        'EGYPT', 'ST HELENA, BRITISH OVERSEAS TERRITORY', 'REUNION',
#        'FRENCH POLYNESIA', 'UNITED KINGDOM', 'UNITED ARAB EMIRATES',
#        'PHILIPPINES', 'INDONESIA', 'CHINA', 'COLUMBIA', 'FIJI',
#        'DOMINICAN REPUBLIC', 'ARUBA', 'MOZAMBIQUE', 'PUERTO RICO',
#        'ATLANTIC OCEAN', 'GREECE', 'ST. MARTIN', 'FRANCE',
#        'PAPUA NEW GUINEA', 'TRINIDAD & TOBAGO', 'KIRIBATI', 'ISRAEL',
#        'DIEGO GARCIA', 'TAIWAN', 'PALESTINIAN TERRITORIES', 'GUAM',
#        'SEYCHELLES', 'BELIZE', 'JAMAICA', 'NIGERIA', 'TONGA', 'SCOTLAND',
#        'CHILE', 'KENYA', 'RUSSIA', 'TURKS & CAICOS', 'AZORES',
#        'SOUTH KOREA', 'MALTA', 'VIETNAM', 'MADAGASCAR',
#        'UNITED ARAB EMIRATES (UAE)', 'PANAMA', 'SOMALIA', 'CROATIA',
#        'NORWAY', 'YEMEN', 'GULF OF ADEN', 'ITALY', 'SIERRA LEONE',
#        'ST. MAARTIN', 'GRAND CAYMAN', 'VANUATU', 'VENEZUELA', 'URUGUAY',
#        'INDIA', 'MICRONESIA', 'CARIBBEAN SEA', 'CANADA', 'OKINAWA',
#        'TANZANIA', 'MARSHALL ISLANDS', 'SENEGAL', 'NORTHERN ARABIAN SEA',
#        'HONG KONG', 'EL SALVADOR', 'ANGOLA', 'IRAN', 'TUNISIA', 'NAMIBIA',
#        'BERMUDA', 'NORTH ATLANTIC OCEAN', 'PORTUGAL', 'SOUTH CHINA SEA',
#        'BANGLADESH', 'PALAU', 'WESTERN SAMOA', 'PACIFIC OCEAN',
#        'BRITISH ISLES', 'GRENADA', 'SRI LANKA', 'IRAQ', 'TURKEY',
#        'SINGAPORE', 'NEW BRITAIN', 'SUDAN', 'JOHNSTON ISLAND',
#        'SOUTH PACIFIC OCEAN', 'NEW GUINEA', 'RED SEA',
#        'NORTH PACIFIC OCEAN', 'FEDERATED STATES OF MICRONESIA',
#        'MID ATLANTIC OCEAN', 'ADMIRALTY ISLANDS', 'BRITISH WEST INDIES',
#        'SOUTH ATLANTIC OCEAN', 'PERSIAN GULF', 'NORTH SEA', 'NICARAGUA',
#        'MALDIVE ISLANDS', 'AMERICAN SAMOA', 'GABON', 'MAYOTTE',
#        'MONTENEGRO', 'THE BALKANS', 'SUDAN?', 'ARGENTINA', 'MARTINIQUE',
#        'INDIAN OCEAN', 'NETHERLANDS ANTILLES', 'LIBERIA', 'SAUDI ARABIA',
#        'NORTHERN MARIANA ISLANDS', 'JAVA', 'CENTRAL PACIFIC',
#        'SOUTHWEST PACIFIC OCEAN', 'BAY OF BENGAL', 'MID-PACIFC OCEAN',
#        'SLOVENIA', 'CURACAO', 'ICELAND', 'BARBADOS', 'CAPE VERDE',
#        'HONDURAS', 'MONACO', 'GUYANA', 'HAITI', 'SAN DOMINGO', 'IRELAND',
#        'KUWAIT', 'REUNION ISLAND', 'FALKLAND ISLANDS', 'CRETE', 'CYPRUS',
#        'EQUATORIAL GUINEA'], dtype=object)

# %% [markdown]
# # 1.6 Cleaning Areas
#
# <img src="https://media.giphy.com/media/l41lFw057lAJQMwg0/giphy.gif" width="400" align="center">
#
# The column 'Areas' is massively diverse, for now we are going to check the NaN rows and see if we can keep them or discart them.

# %%
df['Area'] = df['Area'].astype(str).str.strip()

# %%
df[(df['Area']=='nan')]
# Out:
#              Case Number                                  Date    Year  \
# 32            2018.04.09                           09-Apr-2018  2018.0
# 33            2018.04.05                           05-Apr-2018  2018.0
# 48            2018.01.21                           21-Jan-2018  2018.0
# 56            2017.12.09                           09-Dec-2017  2017.0
# 59          2017.11.25.R                  Reported 25-Nov-2017  2017.0
# 62          2017.11.13.R                  Reported 13-Nov-2017  2017.0
# 90          2017.09.06.R                  Reported 06-Sep-2017  2017.0
# 101           2017.08.18                           18-Aug-2017  2017.0
# 129         2017.06.18.a                           18-Jun-2017  2017.0
# 132         2017.06.14.R                  Reported 14-Jun-2017  2017.0
# 229           2016.08.27                           27-Aug-2016  2016.0
# 248         2016.07.14.R                 Reported  14-Jul-2016  2016.0
# 270         2016.06.02.a                           02-Jun-2016  2016.0
# 296           2016.03.26                           26-Mar-2016  2016.0
# 325           2015.12.19                           19-Dec-2015  2015.0
# 327           2015.12.11                           11-Dec-2015  2015.0
# 370           2015.09.00                              Sep-2015  2015.0
# 388           2015.07.22                           22-Jul-2015  2015.0
# 410           2015.06.19                           19-Jun-2015  2015.0
# 425           2015.05.09                           09-May-2015  2015.0
# 440           2015.03.21                           21-Mar-2015  2015.0
# 446           2015.02.15                           15-Feb-2015  2015.0
# 465         2014.12.28.d                           28-Dec-2014  2014.0
# 469         2014.12.23.R                  Reported 23-Dec-2014  2014.0
# 517         2014.08.09.R                           09-Aug-2014  2014.0
# 538         2014.06.27.R                  Reported 27-Jun-2014  2014.0
# 4229                                       Port Moresby   fishing
# 4252                           Venezuelan aircraft lost     other
# ...
# 966         2010.11.27.R          5337.0         NaN         NaN
# 969           2010.11.15          5334.0         NaN         NaN
# 975           2010.10.25          5328.0         NaN         NaN
# 1002        2010.08.07.a          5301.0         NaN         NaN
# 1088          2009.09.18          5215.0         NaN         NaN
# 1089          2009.09.15          5214.0         NaN         NaN
# 1111        2009.07.11.b          5192.0         NaN         NaN
# 1119        2009.06.14.R          5184.0         NaN         NaN
# 1161        2009.01.27.R          5142.0         NaN         NaN
# 1192        2008.11.09.a          5111.0         NaN         NaN
# 1195          2008.10.21          5108.0         NaN         NaN
# 1224          2008.07.30          5079.0         NaN         NaN
# 1234          2008.07.18          5069.0         NaN         NaN
# 1262          2008.05.01          5041.0         NaN         NaN
# 1275        2008.04.09.R          5028.0         NaN         NaN
# 1365          2007.07.04          4938.0         NaN         NaN
# 1434        2006.09.03.b          4869.0         NaN         NaN
# 1443        2006.08.20.b          4860.0         NaN         NaN
# 1448        2006.08.00.a          4855.0         NaN         NaN
# 1528        2005.11.16.R          4775.0         NaN         NaN
# 1554        2005.09.02.a          4749.0         NaN         NaN
# 1589          2005.05.03          4714.0         NaN         NaN
# 1603          2005.03.25          4700.0         NaN         NaN
# 1697          2004.02.14          4606.0         NaN         NaN
# 1880          2002.02.23          4423.0         NaN         NaN
# 1928          2001.08.03          4375.0         NaN         NaN
# 1973          2001.03.00          4330.0         NaN         NaN
# 2014        2000.09.08.c          4289.0         NaN         NaN
# 2017        2000.09.00.b          4286.0         NaN         NaN
# 2027          2000.08.00          4276.0         NaN         NaN
# 2044          2000.07.00          4259.0         NaN         NaN
# 2053          2000.06.00          4250.0         NaN         NaN
# 2076        2000.01.28.R          4227.0         NaN         NaN
# 2132        1999.03.14.a          4171.0         NaN         NaN
# 2138          1999.01.29          4165.0         NaN         NaN
# 2196          1998.04.00          4107.0         NaN         NaN
# 2265        1997.01.03.a          4038.0         NaN         NaN
# 2269        1996.12.00.b          4034.0         NaN         NaN
# 2305          1996.05.10          3998.0         NaN         NaN
# 2331        1995.11.25.a          3972.0         NaN         NaN
# 2389          1995.05.12          3914.0         NaN         NaN
# 2398          1995.02.00          3905.0         NaN         NaN
# 2441          1994.04.06          3862.0         NaN         NaN
# 2444        1994.03.23.b          3859.0         NaN         NaN
# 2445        1994.03.23.a          3858.0         NaN         NaN
# 2459        1994.00.00.b          3844.0         NaN         NaN
# 2511          1993.01.04          3792.0         NaN         NaN
# 2569          1992.01.06          3734.0         NaN         NaN
# 2594          1991.06.29          3709.0         NaN         NaN
# 2632          1990.06.23          3671.0         NaN         NaN
# 2721          1988.07.23          3582.0         NaN         NaN
# 2722          1988.07.19          3581.0         NaN         NaN
# 2723          1988.07.17          3580.0         NaN         NaN
# 2726        1988.07.04.a          3577.0         NaN         NaN
# 2727          1988.07.00          3576.0         NaN         NaN
# 2733          1988.05.27          3570.0         NaN         NaN
# 2776          1987.07.00          3527.0         NaN         NaN
# 2799          1986.12.00          3504.0         NaN         NaN
# 2819          1986.05.15          3484.0         NaN         NaN
# 2868        1985.00.00.a          3435.0         NaN         NaN
# 2887          1984.08.07          3416.0         NaN         NaN
# 2937          1983.06.15          3366.0         NaN         NaN
# 2970          1982.08.00          3333.0         NaN         NaN
# 2986          1982.03.00          3317.0         NaN         NaN
# 3024        1981.06.15.R          3279.0         NaN         NaN
# 3033          1981.03.08          3270.0         NaN         NaN
# 3056        1980.08.22.R          3247.0         NaN         NaN
# 3071          1980.03.15          3232.0         NaN         NaN
# 3079        1980.00.00.d          3224.0         NaN         NaN
# 3085          1979.12.01          3218.0         NaN         NaN
# 3090          1979.08.28          3213.0         NaN         NaN
# 3157          1977.02.00          3146.0         NaN         NaN
# 3169          1976.09.22          3134.0         NaN         NaN
# 3245        1975.00.00.b          3058.0         NaN         NaN
# 3246        1975.00.00.a          3057.0         NaN         NaN
# 3267        1974.04.25.R          3036.0         NaN         NaN
# 3301          1973.06.13          3002.0         NaN         NaN
# 3338          1972.03.21          2965.0         NaN         NaN
# 3366        1971.04.05.b          2937.0         NaN         NaN
# 3367        1971.04.05.a          2936.0         NaN         NaN
# 3378          1970.11.00          2925.0         NaN         NaN
# 3388          1970.07.05          2915.0         NaN         NaN
# 3395        1970.04.00.b          2908.0         NaN         NaN
# 3396        1970.04.00.a          2907.0         NaN         NaN
# 3399          1970.02.05          2904.0         NaN         NaN
# 3425          1969.08.00          2878.0         NaN         NaN
# 3426          1969.07.27          2877.0         NaN         NaN
# 3434          1969.05.22          2869.0         NaN         NaN
# 3454          1968.10.29          2849.0         NaN         NaN
# 3471          1968.06.00          2832.0         NaN         NaN
# 3487          1968.02.00          2816.0         NaN         NaN
# 3494          1967.12.18          2809.0         NaN         NaN
# 3496          1967.12.14          2807.0         NaN         NaN
# 3499          1967.11.15          2804.0         NaN         NaN
# 3504          1967.10.00          2799.0         NaN         NaN
# 3516        1967.08.14.R          2787.0         NaN         NaN
# 3527          1967.05.09          2776.0         NaN         NaN
# 3543          1966.12.26          2760.0         NaN         NaN
# 3545          1966.11.14          2758.0         NaN         NaN
# 3562          1966.08.14          2741.0         NaN         NaN
# 3572          1966.07.02          2731.0         NaN         NaN
# 3579        1966.05.20.a          2724.0         NaN         NaN
# 3581        1966.05.16.a          2722.0         NaN         NaN
# 3591          1966.01.14          2712.0         NaN         NaN
# 3599          1965.12.19          2704.0         NaN         NaN
# 3605          1965.10.21          2698.0         NaN         NaN
# 3622          1965.06.00          2681.0         NaN         NaN
# 3625        1965.05.00.c          2678.0         NaN         NaN
# 3626        1965.05.00.b          2677.0         NaN         NaN
# 3646        1965.00.00.c          2657.0         NaN         NaN
# 3692        1964.02.17.R          2611.0         NaN         NaN
# 3693        1964.02.14.b          2610.0         NaN         NaN
# 3704          1964.01.27          2599.0         NaN         NaN
# 3736          1963.10.15          2567.0         NaN         NaN
# 3737          1963.09.29          2566.0         NaN         NaN
# 3746        1963.07.10.R          2557.0         NaN         NaN
# 3764          1963.01.30          2539.0         NaN         NaN
# 3773          1963.01.00          2530.0         NaN         NaN
# 3775        1963.00.00.a          2528.0         NaN         NaN
# 3783          1962.11.00          2520.0         NaN         NaN
# 3806          1962.07.20          2497.0         NaN         NaN
# 3877        1961.09.24.a          2426.0         NaN         NaN
# 3884          1961.08.04          2419.0         NaN         NaN
# 3891        1961.07.00.a          2412.0         NaN         NaN
# 3921          1961.02.16          2382.0         NaN         NaN
# 3938        1961.00.00.d          2365.0         NaN         NaN
# 4008          1960.03.28          2295.0         NaN         NaN
# 4065        1959.08.31.R          2238.0         NaN         NaN
# 4122        1959.00.00.e          2181.0         NaN         NaN
# 4140          1958.09.13          2163.0         NaN         NaN
# 4198          1957.05.07          2105.0         NaN         NaN
# 4229          1956.10.00          2074.0         NaN         NaN
# 4252          1956.06.20          2051.0         NaN         NaN
# 4254          1956.05.07          2049.0         NaN         NaN
# 4263          1956.01.16          2040.0         NaN         NaN
# 4297          1955.04.12          2006.0         NaN         NaN
# 4326          1954.09.15          1977.0         NaN         NaN
# 4332          1954.07.28          1971.0         NaN         NaN
# 4337        1954.07.02.R          1966.0         NaN         NaN
# 4341          1954.06.00          1962.0         NaN         NaN
# 4352        1954.00.00.d          1951.0         NaN         NaN
# 4384        1953.03.00.c          1919.0         NaN         NaN
# 4388          1953.02.00          1915.0         NaN         NaN
# 4391        1953.00.00.c          1912.0         NaN         NaN
# 4412          1952.05.00          1891.0         NaN         NaN
# 4430        1951.11.23.R          1873.0         NaN         NaN
# 4441          1951.07.11          1862.0         NaN         NaN
# 4444          1951.05.22          1859.0         NaN         NaN
# 4493        1950.00.00.e          1810.0         NaN         NaN
# 4497        1950.00.00.a          1806.0         NaN         NaN
# 4511          1949.06.13          1792.0         NaN         NaN
# 4540          1948.09.15          1763.0         NaN         NaN
# 4561          1947.12.00          1742.0         NaN         NaN
# 4581          1947.04.00          1722.0         NaN         NaN
# 4598          1946.06.28          1705.0         NaN         NaN
# 4615          1945.09.23          1688.0         NaN         NaN
# 4616          1945.09.19          1687.0         NaN         NaN
# 4627        1945.00.00.d          1676.0         NaN         NaN
# 4635        1944.10.26.b          1668.0         NaN         NaN
# 4638        1944.10.25.a          1665.0         NaN         NaN
# 4639          1944.10.24          1664.0         NaN         NaN
# 4642          1944.09.00          1661.0         NaN         NaN
# 4647        1944.05.24.R          1656.0         NaN         NaN
# 4654          1944.02.18          1649.0         NaN         NaN
# 4659        1944.00.00.c          1644.0         NaN         NaN
# 4670        1943.07.00.b          1633.0         NaN         NaN
# 4674        1943.05.17.b          1629.0         NaN         NaN
# 4675        1943.05.17.a          1628.0         NaN         NaN
# 4677        1943.05.01.R          1626.0         NaN         NaN
# 4680          1943.03.14          1623.0         NaN         NaN
# 4681        1943.03.02.b          1622.0         NaN         NaN
# 4685        1943.00.00.e          1618.0         NaN         NaN
# 4686        1943.00.00.d          1617.0         NaN         NaN
# 4693          1942.11.16          1610.0         NaN         NaN
# 4694          1942.11.21          1609.0         NaN         NaN
# 4695        1942.11.13.c          1608.0         NaN         NaN
# 4696        1942.11.13.b          1607.0         NaN         NaN
# 4697        1942.11.13.a          1606.0         NaN         NaN
# 4703        1942.09.12.b          1600.0         NaN         NaN
# 4705          1942.09.11          1598.0         NaN         NaN
# 4706          1942.08.08          1597.0         NaN         NaN
# 4707          1942.07.12          1596.0         NaN         NaN
# 4709        1942.06.11.R          1594.0         NaN         NaN
# 4726        1942.00.00.e          1577.0         NaN         NaN
# 4728        1942.00.00.c          1575.0         NaN         NaN
# 4729        1942.00.00.b          1574.0         NaN         NaN
# 4731          1941.12.07          1572.0         NaN         NaN
# 4737          1941.09.25          1566.0         NaN         NaN
# 4745          1941.03.24          1558.0         NaN         NaN
# 4750          1941.01.00          1553.0         NaN         NaN
# 4757        1941.00.00.a          1546.0         NaN         NaN
# 4788        1939.11.02.R          1515.0         NaN         NaN
# 4793          1939.07.18          1510.0         NaN         NaN
# 4802        1939.00.00.e          1501.0         NaN         NaN
# 4812        1938.07.17.R          1491.0         NaN         NaN
# 4826      1938.00.00.e.R          1477.0         NaN         NaN
# 4833        1937.11.06.R          1470.0         NaN         NaN
# 4847        1937.06.28.R          1456.0         NaN         NaN
# 4867        1936.09.11.R          1436.0         NaN         NaN
# 4902          1935.07.05          1401.0         NaN         NaN
# 4911        1935.04.12.R          1392.0         NaN         NaN
# 4955        1933.09.27.R          1348.0         NaN         NaN
# 4976          1932.11.09          1327.0         NaN         NaN
# 5002          1931.09.27          1301.0         NaN         NaN
# 5022          1931.03.15          1281.0         NaN         NaN
# 5029        1931.00.00.a          1274.0         NaN         NaN
# 5036        1930.09.12.R          1267.0         NaN         NaN
# 5044        1930.05.11.R          1259.0         NaN         NaN
# 5053          1930.01.00          1250.0         NaN         NaN
# 5054        1930.00.00.c          1249.0         NaN         NaN
# 5060        1929.12.09.R          1243.0         NaN         NaN
# 5087        1929.01.06.R          1216.0         NaN         NaN
# 5094          1928.12.21          1209.0         NaN         NaN
# 5096        1928.11.15.R          1207.0         NaN         NaN
# 5101          1928.07.11          1202.0         NaN         NaN
# 5107          1928.04.09          1196.0         NaN         NaN
# 5124          1927.10.00          1179.0         NaN         NaN
# 5143        1926.10.23.a          1160.0         NaN         NaN
# 5144        1926.09.06.R          1159.0         NaN         NaN
# 5158        1926.00.00.b          1145.0         NaN         NaN
# 5232        1922.01.28.R          1071.0         NaN         NaN
# 5245          1921.07.21          1058.0         NaN         NaN
# 5275        1900.00.00.R          1028.0         NaN         NaN
# 5291          1917.05.05          1012.0         NaN         NaN
# 5296          1916.11.15          1007.0         NaN         NaN
# 5307          1916.07.11           996.0         NaN         NaN
# 5313        1916.06.24.R           990.0         NaN         NaN
# 5323      1915.07.06.a.R           980.0         NaN         NaN
# 5349        1913.12.26.R           954.0         NaN         NaN
# 5358        1913.07.10.R           945.0         NaN         NaN
# 5366        1912.11.30.R           937.0         NaN         NaN
# 5400        1910.06.25.R           903.0         NaN         NaN
# 5480  1906.04.10.R.a & b           823.0         NaN         NaN
# 5513        1904.00.00.R           790.0         NaN         NaN
# 5519          1903.07.00           784.0         NaN         NaN
# 5525        1903.00.00.b           778.0         NaN         NaN
# 4934                 NaN             NaN         NaN         NaN
# 5978                 NaN             NaN         NaN         NaN

# %%
df = df.drop(index=[4934])
df = df.drop(index=[5978])

# %%
df.to_csv('attacks_cleaned.csv')

# %%
df1 = pd.read_csv('attacks_cleaned.csv')

# %%
df1.head(5)
# Out:
#    Unnamed: 0 Case Number         Date    Year        Type    Country  \
# 0           0  2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1           1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2           2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3           3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4           4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
#
#               Area                        Location Activity             Name  \
# 0       California     Oceanside, San Diego County    other      Julie Wolfe
# 1          Georgia  St. Simon Island, Glynn County    other  Adyson McNeely
# 2           Hawaii                    Habush, Oahu  surfing      John Denges
# 3  New South Wales              Arrawarra Headland  surfing             male
# 4           Colima                        La Ticla   diving   Gustavo Ramos
#
#   Sex   Age                                             Injury Fatal  \
# 0    F   57  no injury to occupant, outrigger canoe and pad...    No
# 1    F   11                         minor injury to left thigh    No
# 2    M   48       injury to left lower leg from surfboard skeg    No
# 3    M  NaN                          minor injury to lower leg    No
# 4    M  NaN  lacerations to leg & hand shark provoked incident    No
#
#             Time          Species          Investigator or Source  \
# 0          18h00      white shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25          6303.0         NaN         NaN
# 1    2018.06.18          6302.0         NaN         NaN
# 2    2018.06.09          6301.0         NaN         NaN
# 3    2018.06.08          6300.0         NaN         NaN
# 4    2018.06.04          6299.0         NaN         NaN

# %% [markdown]
#  # 2.0  Analysis of the Shark Attacks
#
#
#  In this section we are going to check the data from our data frame by taking a look on the charts.

# %% [markdown]
# ###  Death rate:
#
#
# Checking the data from all the attacks, the chart shows that about 80% of all the attacks are non lethal.

# %%
fatal_plot = df1['Fatal'].value_counts()
fig1, ax1 = plt.subplots()  
fig1 = plt.gcf()
fig1.set_size_inches(18.5, 10.5)
ax1.pie(fatal_plot, labels=fatal_plot.index, autopct="%1.1f%%", shadow=False, startangle=90)
plt.legend(fatal_plot.index, loc='upper left')
ax1.axis("equal")  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.100277796175415,
#  1.1007269972935398,
#  -1.1004821940329008,
#  1.1000229616206143)

# %%
# fatalis = df['Fatal'].value_counts()

# %% [markdown]
# ###  2.1 Death Rate by country:
#
# Although  USA has the largest amount of attacks by sharks, comparing the death rate from the other contries, it is not the deadliest. Surprisely  most of the attacks in Philipnes are deadly.

# %%
mask = df1['Country'].value_counts().loc[lambda x : x>52]

# %%
df1['Country'].value_counts()[:10]
# Out:
# USA                 1906
# AUSTRALIA           1084
# SOUTH AFRICA         487
# PAPUA NEW GUINEA     128
# BRAZIL               100
# BAHAMAS               95
# NEW ZEALAND           89
# MEXICO                70
# REUNION               58
# PHILIPPINES           55
# Name: Country, dtype: int64

# %%
df1['Country'].value_counts(normalize=True)[:10]
# Out:
# USA                 0.374754
# AUSTRALIA           0.213134
# SOUTH AFRICA        0.095753
# PAPUA NEW GUINEA    0.025167
# BRAZIL              0.019662
# BAHAMAS             0.018679
# NEW ZEALAND         0.017499
# MEXICO              0.013763
# REUNION             0.011404
# PHILIPPINES         0.010814
# Name: Country, dtype: float64

# %%
country_top10= df1.query('Country in ["USA","AUSTRALIA","SOUTH AFRICA","PAPUA NEW GUINEA","BRAZIL","BAHAMAS","NEW ZEALAND","MEXICO","REUNION","PHILIPPINES"]')

# %%
fatality_rate = country_top10.groupby('Country').Fatal.apply(lambda x: (x == 'Yes').mean()).sort_values(ascending=True).nlargest(10)

# %%
fatality_rate
# Out:
# Country
# PHILIPPINES         0.600000
# MEXICO              0.500000
# REUNION             0.482759
# PAPUA NEW GUINEA    0.421875
# BRAZIL              0.350000
# AUSTRALIA           0.201107
# SOUTH AFRICA        0.176591
# NEW ZEALAND         0.134831
# USA                 0.069255
# BAHAMAS             0.052632
# Name: Fatal, dtype: float64

# %% [markdown]
# #### 2.2.1 top 10 deadliest countries:

# %%
fig, ax = plt.subplots()  
fig = plt.gcf()
fig.set_size_inches(15, 10.5)

fatality_rate.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# #### 2.2.2 top 10 deadliest activities

# %%
activity_death_rate = country_top10.groupby('Activity').Fatal.apply(lambda x: (x == 'Yes').mean()).sort_values(ascending=True).nlargest(10)

# %%
fig, ax = plt.subplots()  
fig = plt.gcf()
fig.set_size_inches(15, 10.5)

activity_death_rate.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Activity'>

# %% [markdown]
# ## 2.2 Activities:

# %% [markdown]
# the party of surfists may be in danger depending where they are going to choose to surf. As we can see one of the most attacked activities is Surfing.

# %%
sns.countplot(y="Activity", data=df1, color="c")
plt.show()

# %%
surfing_attack_rate = country_top10.groupby('Country').Activity.apply(lambda x: (x == 'surfing').mean()).sort_values(ascending=True).nlargest(10)

# %% [markdown]
# Taking a closer look at the countries where most of the attacks happened while surfing.

# %%
fig, ax = plt.subplots()  
fig = plt.gcf()
fig.set_size_inches(10, 8.5)
surfing_attack_rate.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %% [markdown]
# # 3.0    Mapping the attacks

# %% [markdown]
# ### Giving a  close location to where the attacks happened.
#
# the problem of the map is that we are going to lose a lot of data from the columns activities, types and other stuff, this is why we are going to analyse this by the end of our analysis.
#
# Most of the data was lost because Latitude and Logitude were not found. This leave us with around 2,5k data rows.

# %%
df['address']=df['Location']+','+df['Area']+','+df['Country']
df['Latitude']='NaN'
df['Longitude']='NaN'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5086 entries, 0 to 5550
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             5085 non-null   object
#  1   Date                    5086 non-null   object
#  2   Year                    5086 non-null   float64
#  3   Type                    5084 non-null   object
#  4   Country                 5086 non-null   object
#  5   Area                    5086 non-null   object
#  6   Location                4751 non-null   object
#  7   Activity                5086 non-null   object
#  8   Name                    4965 non-null   object
#  9   Sex                     4651 non-null   object
#  10  Age                     3155 non-null   object
#  11  Injury                  5086 non-null   object
#  12  Fatal                   5086 non-null   object
#  13  Time                    2704 non-null   object
#  14  Species                 5086 non-null   object
#  15  Investigator or Source  5074 non-null   object
#  16  pdf                     5086 non-null   object
#  17  href formula            5085 non-null   object
#  18  href                    5086 non-null   object
#  19  Case Number.1           5086 non-null   object
#  20  Case Number.2           5086 non-null   object
#  21  original order          5086 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             1 non-null      object
#  24  address                 4751 non-null   object
#  25  Latitude                5086 non-null   object
#  26  Longitude               5086 non-null   object
# dtypes: float64(2), object(25)
# memory usage: 1.1+ MB

# %%
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm
from numba import jit

# %%
@jit
def defining_Loc():

    for index, row in tqdm(df.iterrows()):
        address = row['address']
        geolocator=Nominatim(user_agent="Shark_attack", timeout=3)
        location = geolocator.geocode(address)
        if location is None:
            df.loc[index, 'Latitude'] = None
            df.loc[index, 'Longitude'] = None
        else:
            df.loc[index, 'Latitude'] = location.latitude
            df.loc[index, 'Longitude'] = location.longitude

# %%
# defining_Loc()

# %%
df['Latitude'] = df['Latitude'].replace('NaN', np.nan)
df['Longitude'] = df['Longitude'].replace('NaN', np.nan)
df = df.dropna(axis=0, subset=['Latitude'])
df = df.dropna(axis=0, subset=['address'])

# %%
# df.to_csv('attacks_with_loc.csv')

# %%
shark_attacks = pd.read_csv('./attacks_with_loc.csv')

# %%
shark_attacks.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Injury', 'Fatal', 'Time', 'Species', 'address', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
# shark_attacks.drop(['Unnamed: 0','Case Number','Name','Sex ','Age','Unnamed: 23','original order','Case Number.1','Case Number.2','href','href formula','Investigator or Source','pdf','Unnamed: 22'], axis = 1,inplace =True)

# %%
shark_attacks.head(5)
# Out:
#    Unnamed: 0         Date    Year        Type    Country             Area  \
# 0           0  25-Jun-2018  2018.0     Boating        USA       California
# 1           1  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 2           2  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 3           3  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 4           4  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#                        Location  Activity  \
# 0   Oceanside, San Diego County     other
# 1            Arrawarra Headland   surfing
# 2            Flat Rock, Ballina   surfing
# 3         Piedade Beach, Recife  swimming
# 4  Cocoa Beach, Brevard  County   walking
#
#                                               Injury Fatal            Time  \
# 0  no injury to occupant, outrigger canoe and pad...    No           18h00
# 1                          minor injury to lower leg    No             NaN
# 2                            no injury, board bitten    No             NaN
# 3                                              fatal   Yes  Late afternoon
# 4                              lower left leg bitten    No           17h00
#
#           Species                                       address   Latitude  \
# 0     white shark    Oceanside, San Diego County,California,USA  33.195870
# 1       2 m shark  Arrawarra Headland,New South Wales,AUSTRALIA -30.060426
# 2             NaN  Flat Rock, Ballina,New South Wales,AUSTRALIA -28.842955
# 3     tiger shark       Piedade Beach, Recife,Pernambuco,BRAZIL  -8.176058
# 4  bull shark, 6'      Cocoa Beach, Brevard  County,Florida,USA  28.319474
#
#     Longitude
# 0 -117.379483
# 1  153.201685
# 2  153.607990
# 3  -34.917877
# 4  -80.610259

# %%
# shark_attacks.to_csv('attacks_with_loc.csv')

# %%
shark_attacks[["Longitude", "Latitude"]] = shark_attacks[["Longitude", "Latitude"]].apply(pd.to_numeric)

# %%
# create map of Portland with Breweries using latitude and longitude values
latitude = 0
longitude = 0
mapping_attacks = folium.Map(location=[latitude, longitude], zoom_start=1.5)
for lat, lng in zip(shark_attacks['Latitude'], 
shark_attacks['Longitude']):
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        color='red',
        fill=True,
        fill_color='#000000',
        fill_opacity=0.5,
        parse_html=False).add_to(mapping_attacks)

# %% [markdown]
# While filtering the countries, most of the attacks  around 60% of all the attacks
# happened either in USA or Australia, although most of the attacks at these areas were non lethal, it is a good idea for our surfists to avoid surfing onto these beaches.

# %%
mapping_attacks
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
